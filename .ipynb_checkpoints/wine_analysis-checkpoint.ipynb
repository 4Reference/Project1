# %% [markdown]
# # Wines Review Analysis

# %%
#Dependancies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import re
import scipy.stats as st

# %%
wines_csv = "dropped_wine_data.csv"
wine_df = pd.read_csv(wines_csv)
wine_df.head()
# Out:
#    Unnamed: 0   country  points  price           province  \
# 0           0     Italy      87    NaN  Sicily & Sardinia
# 1           1  Portugal      87   15.0              Douro
# 2           2        US      87   14.0             Oregon
# 3           3        US      87   13.0           Michigan
# 4           4        US      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
print([wine_df.count()])
# Out:
# [Unnamed: 0     129971
# country        129908
# points         129971
# price          120975
# province       129908
# region_1       108724
# region_2        50511
# taster_name    103727
# title          129971
# variety        129970
# winery         129971
# dtype: int64]

# %%
#drop old index from data
wine_df2 = wine_df.drop(columns='Unnamed: 0', axis=1)
print([wine_df2])
wine_df2.info()
# Out:
# [         country  points  price           province             region_1  \
# 0          Italy      87    NaN  Sicily & Sardinia                 Etna
# 1       Portugal      87   15.0              Douro                  NaN
# 2             US      87   14.0             Oregon    Willamette Valley
# 3             US      87   13.0           Michigan  Lake Michigan Shore
# 4             US      87   65.0             Oregon    Willamette Valley
# ...          ...     ...    ...                ...                  ...
# 129966   Germany      90   28.0              Mosel                  NaN
# 129967        US      90   75.0             Oregon               Oregon
# 129968    France      90   30.0             Alsace               Alsace
# 129969    France      90   32.0             Alsace               Alsace
# 129970    France      90   21.0             Alsace               Alsace
#
#                  region_2         taster_name  \
# 0                     NaN       Kerin O’Keefe
# 1                     NaN          Roger Voss
# 2       Willamette Valley        Paul Gregutt
# 3                     NaN  Alexander Peartree
# 4       Willamette Valley        Paul Gregutt
# ...                   ...                 ...
# 129966                NaN  Anna Lee C. Iijima
# 129967       Oregon Other        Paul Gregutt
# 129968                NaN          Roger Voss
# 129969                NaN          Roger Voss
# 129970                NaN          Roger Voss
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 10 columns]]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 10 columns):
# country        129908 non-null object
# points         129971 non-null int64
# price          120975 non-null float64
# province       129908 non-null object
# region_1       108724 non-null object
# region_2       50511 non-null object
# taster_name    103727 non-null object
# title          129971 non-null object
# variety        129970 non-null object
# winery         129971 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 9.9+ MB

# %%
#Create single region column
index = 0

for index, row in wine_df2.iterrows():
    if wine_df2.loc[index, 'region_1'] == wine_df2.loc[index, 'region_2']:
        wine_df2.loc[index, 'region_2'] = np.nan

wine_df2
# Out:
#          country  points  price           province             region_1  \
# 0          Italy      87    NaN  Sicily & Sardinia                 Etna
# 1       Portugal      87   15.0              Douro                  NaN
# 2             US      87   14.0             Oregon    Willamette Valley
# 3             US      87   13.0           Michigan  Lake Michigan Shore
# 4             US      87   65.0             Oregon    Willamette Valley
# ...          ...     ...    ...                ...                  ...
# 129966   Germany      90   28.0              Mosel                  NaN
# 129967        US      90   75.0             Oregon               Oregon
# 129968    France      90   30.0             Alsace               Alsace
# 129969    France      90   32.0             Alsace               Alsace
# 129970    France      90   21.0             Alsace               Alsace
#
#             region_2         taster_name  \
# 0                NaN       Kerin O’Keefe
# 1                NaN          Roger Voss
# 2                NaN        Paul Gregutt
# 3                NaN  Alexander Peartree
# 4                NaN        Paul Gregutt
# ...              ...                 ...
# 129966           NaN  Anna Lee C. Iijima
# 129967  Oregon Other        Paul Gregutt
# 129968           NaN          Roger Voss
# 129969           NaN          Roger Voss
# 129970           NaN          Roger Voss
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 10 columns]

# %%
print([wine_df2.count()])
wine_df2.info()
# Out:
# [country        129908
# points         129971
# price          120975
# province       129908
# region_1       108724
# region_2        45239
# taster_name    103727
# title          129971
# variety        129970
# winery         129971
# dtype: int64]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 10 columns):
# country        129908 non-null object
# points         129971 non-null int64
# price          120975 non-null float64
# province       129908 non-null object
# region_1       108724 non-null object
# region_2       45239 non-null object
# taster_name    103727 non-null object
# title          129971 non-null object
# variety        129970 non-null object
# winery         129971 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 9.9+ MB

# %%
wine_df2
# Out:
#          country  points  price           province             region_1  \
# 0          Italy      87    NaN  Sicily & Sardinia                 Etna
# 1       Portugal      87   15.0              Douro                  NaN
# 2             US      87   14.0             Oregon    Willamette Valley
# 3             US      87   13.0           Michigan  Lake Michigan Shore
# 4             US      87   65.0             Oregon    Willamette Valley
# ...          ...     ...    ...                ...                  ...
# 129966   Germany      90   28.0              Mosel                  NaN
# 129967        US      90   75.0             Oregon               Oregon
# 129968    France      90   30.0             Alsace               Alsace
# 129969    France      90   32.0             Alsace               Alsace
# 129970    France      90   21.0             Alsace               Alsace
#
#             region_2         taster_name  \
# 0                NaN       Kerin O’Keefe
# 1                NaN          Roger Voss
# 2                NaN        Paul Gregutt
# 3                NaN  Alexander Peartree
# 4                NaN        Paul Gregutt
# ...              ...                 ...
# 129966           NaN  Anna Lee C. Iijima
# 129967  Oregon Other        Paul Gregutt
# 129968           NaN          Roger Voss
# 129969           NaN          Roger Voss
# 129970           NaN          Roger Voss
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 10 columns]

# %%
wine_df3 = wine_df.drop('region_2', axis=1)
wine_df3.count()
# Out:
# Unnamed: 0     129971
# country        129908
# points         129971
# price          120975
# province       129908
# region_1       108724
# taster_name    103727
# title          129971
# variety        129970
# winery         129971
# dtype: int64

# %%
clean_wine_df3 = wine_df3.dropna()
clean_wine_df3
# Out:
#         Unnamed: 0 country  points  price           province  \
# 2                2      US      87   14.0             Oregon
# 3                3      US      87   13.0           Michigan
# 4                4      US      87   65.0             Oregon
# 5                5   Spain      87   15.0     Northern Spain
# 6                6   Italy      87   16.0  Sicily & Sardinia
# ...            ...     ...     ...    ...                ...
# 129965      129965  France      90   28.0             Alsace
# 129967      129967      US      90   75.0             Oregon
# 129968      129968  France      90   30.0             Alsace
# 129969      129969  France      90   32.0             Alsace
# 129970      129970  France      90   21.0             Alsace
#
#                    region_1         taster_name  \
# 2         Willamette Valley        Paul Gregutt
# 3       Lake Michigan Shore  Alexander Peartree
# 4         Willamette Valley        Paul Gregutt
# 5                   Navarra   Michael Schachner
# 6                  Vittoria       Kerin O’Keefe
# ...                     ...                 ...
# 129965               Alsace          Roger Voss
# 129967               Oregon        Paul Gregutt
# 129968               Alsace          Roger Voss
# 129969               Alsace          Roger Voss
# 129970               Alsace          Roger Voss
#
#                                                     title             variety  \
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 6        Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
# ...                                                   ...                 ...
# 129965  Domaine Rieflé-Landmann 2013 Seppi Landmann Va...          Pinot Gris
# 129967                  Citation 2004 Pinot Noir (Oregon)          Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                          winery
# 2                     Rainstorm
# 3                    St. Julian
# 4                  Sweet Cheeks
# 5                        Tandem
# 6               Terre di Giurfo
# ...                         ...
# 129965  Domaine Rieflé-Landmann
# 129967                 Citation
# 129968          Domaine Gresser
# 129969     Domaine Marcel Deiss
# 129970         Domaine Schoffit
#
# [77267 rows x 10 columns]

# %%
# Find Califorinian wines
california_wines = wine_df2.loc[wine_df2['province'] == "California"]
california_wines
# Out:
#        country  points  price    province           region_1       region_2  \
# 10          US      87   19.0  California        Napa Valley           Napa
# 12          US      87   34.0  California   Alexander Valley         Sonoma
# 14          US      87   12.0  California      Central Coast            NaN
# 23          US      87   22.0  California        Paso Robles  Central Coast
# 25          US      87   69.0  California       Sonoma Coast         Sonoma
# ...        ...     ...    ...         ...                ...            ...
# 129942      US      90   35.0  California      Sonoma County         Sonoma
# 129945      US      90   20.0  California  Santa Ynez Valley  Central Coast
# 129949      US      90   35.0  California        Napa Valley           Napa
# 129950      US      90   35.0  California        Napa Valley           Napa
# 129952      US      90   22.0  California      Chiles Valley           Napa
#
#            taster_name                                              title  \
# 10      Virginie Boone  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 12      Virginie Boone  Louis M. Martini 2012 Cabernet Sauvignon (Alex...
# 14       Matt Kettmann           Mirassou 2012 Chardonnay (Central Coast)
# 23       Matt Kettmann  Bianchi 2011 Signature Selection Merlot (Paso ...
# 25      Virginie Boone  Castello di Amorosa 2011 King Ridge Vineyard P...
# ...                ...                                                ...
# 129942  Virginie Boone   Arrowood 2010 Cabernet Sauvignon (Sonoma County)
# 129945   Matt Kettmann  Birichino 2013 Jurassic Park Vineyard Old Vine...
# 129949  Virginie Boone  Flora Springs 2013 Barrel Fermented Chardonnay...
# 129950  Virginie Boone  Hendry 2012 Blocks 7 & 22 Zinfandel (Napa Valley)
# 129952  Virginie Boone             Houdini 2011 Zinfandel (Chiles Valley)
#
#                    variety               winery
# 10      Cabernet Sauvignon   Kirkland Signature
# 12      Cabernet Sauvignon     Louis M. Martini
# 14              Chardonnay             Mirassou
# 23                  Merlot              Bianchi
# 25              Pinot Noir  Castello di Amorosa
# ...                    ...                  ...
# 129942  Cabernet Sauvignon             Arrowood
# 129945        Chenin Blanc            Birichino
# 129949          Chardonnay        Flora Springs
# 129950           Zinfandel               Hendry
# 129952           Zinfandel              Houdini
#
# [36247 rows x 10 columns]

# %%
clean_ca_wines = california_wines.dropna()
clean_ca_wines = clean_ca_wines.reset_index()
clean_ca_wines
# Out:
#         index country  points  price    province           region_1  \
# 0          10      US      87   19.0  California        Napa Valley
# 1          12      US      87   34.0  California   Alexander Valley
# 2          23      US      87   22.0  California        Paso Robles
# 3          25      US      87   69.0  California       Sonoma Coast
# 4          29      US      86   16.0  California         Clarksburg
# ...       ...     ...     ...    ...         ...                ...
# 17403  129942      US      90   35.0  California      Sonoma County
# 17404  129945      US      90   20.0  California  Santa Ynez Valley
# 17405  129949      US      90   35.0  California        Napa Valley
# 17406  129950      US      90   35.0  California        Napa Valley
# 17407  129952      US      90   22.0  California      Chiles Valley
#
#              region_2     taster_name  \
# 0                Napa  Virginie Boone
# 1              Sonoma  Virginie Boone
# 2       Central Coast   Matt Kettmann
# 3              Sonoma  Virginie Boone
# 4      Central Valley  Virginie Boone
# ...               ...             ...
# 17403          Sonoma  Virginie Boone
# 17404   Central Coast   Matt Kettmann
# 17405            Napa  Virginie Boone
# 17406            Napa  Virginie Boone
# 17407            Napa  Virginie Boone
#
#                                                    title             variety  \
# 0      Kirkland Signature 2011 Mountain Cuvée Caberne...  Cabernet Sauvignon
#
  Citation 2004 Pinot Noir (Oregon)          Pinot Noir
#
#                    winery
# 0               Rainstorm
# 1            Sweet Cheeks
# 2      Kirkland Signature
# 3        Louis M. Martini
# 4                Mirassou
# ...                   ...
# 34554           Birichino
# 34555       Flora Springs
# 34556              Hendry
# 34557             Houdini
# 34558            Citation
#
# [34559 rows x 12 columns]

# %%
clean_gbl_wines_noca = clean_gbl_wines.loc[clean_gbl_wines['province'] != "California"]
clean_gbl_wines_noca = clean_gbl_wines_noca.reset_index()
clean_gbl_wines_noca
# Out:
#        level_0   index  Unnamed: 0 country  points  price    province  \
# 0            0       2           2      US      87   14.0      Oregon
# 1            1       4           4      US      87   65.0      Oregon
# 2            5      21          21      US      87   20.0      Oregon
# 3            9      35          35      US      86   50.0      Oregon
# 4           10      41          41      US      86   22.0      Oregon
# ...        ...     ...         ...     ...     ...    ...         ...
# 16170    34549  129919      129919      US      91  105.0  Washington
# 16171    34550  129926      129926      US      91   41.0  Washington
# 16172    34551  129927      129927      US      91   28.0  Washington
# 16173    34552  129935      129935      US      91   38.0  Washington
# 16174    34558  129967      129967      US      90   75.0      Oregon
#
#                                  region_1           region_2   taster_name  \
# 0                       Willamette Valley  Willamette Valley  Paul Gregutt
# 1                       Willamette Valley  Willamette Valley  Paul Gregutt
# 2                                  Oregon       Oregon Other  Paul Gregutt
# 3                             McMinnville  Willamette Valley  Paul Gregutt
# 4                       Willamette Valley  Willamette Valley  Paul Gregutt
# ...                                   ...                ...           ...
# 16170             Walla Walla Valley (WA)    Columbia Valley  Paul Gregutt
# 16171             Walla Walla Valley (WA)    Columbia Valley  Paul Gregutt
# 16172                Columbia Valley (WA)    Columbia Valley  Paul Gregutt
# 16173  Columbia Valley-Walla Walla Valley    Columbia Valley  Paul Gregutt
# 16174                              Oregon       Oregon Other  Paul Gregutt
#
#                                                    title         variety  \
# 0          Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 1      Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# 2                       Acrobat 2013 Pinot Noir (Oregon)      Pinot Noir
# 3             Erath 2010 Hyland Pinot Noir (McMinnville)      Pinot Noir
# 4      Hawkins Cellars 2009 Pinot Noir (Willamette Va...      Pinot Noir
# ...                                                  ...             ...
# 16170  Nicholas Cole Cellars 2004 Reserve Red (Walla ...       Red Blend
# 16171  Reininger 2005 Ash Hollow Vineyard Syrah (Wall...           Syrah
# 16172  Tamarack Cellars 2006 Cabernet Franc (Columbia...  Cabernet Franc
# 16173  Va Piano 2006 Syrah (Columbia Valley-Walla Wal...           Syrah
# 16174                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
#
#                       winery
# 0                  Rainstorm
# 1               Sweet Cheeks
# 2                    Acrobat
# 3                      Erath
# 4            Hawkins Cellars
# ...                      ...
# 16170  Nicholas Cole Cellars
# 16171              Reininger
# 16172       Tamarack Cellars
# 16173               Va Piano
# 16174               Citation
#
# [16175 rows x 13 columns]

# %%
#ordered list of counts of CA wines
ca_varietal = clean_ca_wines.groupby('variety')
ca_type_count = ca_varietal['title'].count()
print([ca_type_count.sort_values(ascending=False).head(20)])
t20_ca_type_count = ca_type_count.sort_values(ascending=False).head(20)
t20_ca_type_count.plot.pie(figsize=(17,17),subplots=True,autopct='%1.1f%%')
# Out:
# [variety
# Pinot Noir                  3492
# Chardonnay                  2482
# Cabernet Sauvignon          2441
# Zinfandel                   1351
# Red Blend                    938
# Syrah                        871
# Sauvignon Blanc              806
# Merlot                       506
# Bordeaux-style Red Blend     394
# Petite Sirah                 352
# Rhône-style Red Blend        299
# Rosé                         291
# Grenache                     235
# Viognier                     225
# Sparkling Blend              218
# Cabernet Franc               187
# White Blend                  161
# Pinot Grigio                 127
# Barbera                      127
# Malbec                       118
# Name: title, dtype: int64]
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000266B48E8288>],
#       dtype=object)

# %%
gbl_varietal = clean_gbl_wines.groupby('variety')
gbl_type_count = gbl_varietal['title'].count()
print([gbl_type_count.sort_values(ascending=False).head(20)])
t20_gbl_type_count = gbl_type_count.sort_values(ascending=False).head(20)
t20_gbl_type_count.plot.pie(figsize=(17,17),subplots=True,autopct='%1.1f%%')
# Out:
# [variety
# Pinot Noir                  6260
# Cabernet Sauvignon          4081
# Chardonnay                  4005
# Syrah                       2254
# Red Blend                   2058
# Riesling                    1470
# Zinfandel                   1449
# Merlot                      1362
# Bordeaux-style Red Blend    1248
# Sauvignon Blanc             1178
# Pinot Gris                   710
# Cabernet Franc               698
# Rosé                         667
# Rhône-style Red Blend        527
# Viognier                     498
# Malbec                       445
# Petite Sirah                 417
# White Blend                  406
# Grenache                     394
# Sparkling Blend              358
# Name: title, dtype: int64]
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000266B48425C8>],
#       dtype=object)

# %%
noca_gbl_varietal = clean_gbl_wines_noca.groupby('variety')
noca_gbl_type_count = noca_gbl_varietal['title'].count()
print([noca_gbl_type_count.sort_values(ascending=False).head(20)])
t20_noca_gbl_type_count = noca_gbl_type_count.sort_values(ascending=False).head(20)
t20_noca_gbl_type_count.plot.pie(figsize=(17,17),subplots=True,autopct='%1.1f%%')
# Out:
# [variety
# Pinot Noir                  2688
# Cabernet Sauvignon          1536
# Chardonnay                  1418
# Riesling                    1365
# Syrah                       1314
# Red Blend                   1004
# Bordeaux-style Red Blend     843
# Merlot                       829
# Pinot Gris                   631
# Cabernet Franc               497
# Rosé                         343
# Sauvignon Blanc              324
# Malbec                       320
# Viognier                     256
# Gewürztraminer               250
# White Blend                  205
# Rhône-style Red Blend        187
# Tempranillo                  180
# Sangiovese                   158
# Grenache                     145
# Name: title, dtype: int64]
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000266B9E63148>],
#       dtype=object)

# %%
# extract year from column title
clean_ca_wines_yr = clean_ca_wines.copy()

for index, row in clean_ca_wines_yr.iterrows():
    if len(''.join(filter(lambda i: i.isdigit(), clean_ca_wines_yr['title'][index]))) == 4:
        clean_ca_wines_yr.loc[index, 'year'] = ''.join(filter(lambda i: i.isdigit(), clean_ca_wines_yr['title'][index]))

print([clean_ca_wines_yr.count()])
reclean_ca_wines_yr = clean_ca_wines_yr.dropna()
reclean_ca_wines_yr.count()
# Out:
# [index          17408
# country        17408
# points         17408
# price          17408
# province       17408
# region_1       17408
# region_2       17408
# taster_name    17408
# title          17408
# variety        17408
# winery         17408
# year           16528
# dtype: int64]
# index          16528
# country        16528
# points         16528
# price          16528
# province       16528
# region_1       16528
# region_2       16528
# taster_name    16528
# title          16528
# variety        16528
# winery         16528
# year           16528
# dtype: int64

# %%
# points vs price
plt.figure(figsize=(17, 17))
plt.scatter(clean_ca_wines['points'], clean_ca_wines['price'], alpha=.75, edgecolors="k")
# x,y required , alpha sets opacity, edgecolors help datapoint stand out https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html
plt.title(f"CA Wines Points vs Price Scatter")
plt.ylabel("Price ($)")
plt.xlabel("Reviewed Point Value")
plt.grid(True) 
plt.tight_layout() 
# tight_layout. This module provides routines to adjust subplot params so that subplots are nicely fit in the figure. https://matplotlib.org/api/tight_layout_api.html
plt.show()

# %%
x_values = clean_ca_wines['points'].astype(float)
y_values = clean_ca_wines['price'].astype(float)

# Calculate Pearson r value
print(f"The correlation coefficient between Review Points and Price is {round(st.pearsonr(x_values,y_values)[0],2)} for CA Wines")

# Calculate line for plot
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot and labels

plt.figure(figsize=(17, 17))
plt.title(f"CA Wines Points vs Price LinReg")
plt.scatter(x_values,y_values, alpha=.75, edgecolors="k") 
# x,y required , alpha sets opacity, edgecolors help datapoint stand out https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(80,500),fontsize=15,color="red")
plt.ylabel("Price ($)")
plt.xlabel("Reviewed Point Value")
plt.grid(True) 
plt.tight_layout() 
plt.show()
# Out:
# The correlation coefficient between Review Points and Price is 0.39

# %%
# GBL no CA points vs price
plt.figure(figsize=(17, 17))
plt.scatter(clean_gbl_wines_noca['points'], clean_gbl_wines_noca['price'], alpha=.75, edgecolors="k")
# x,y required , alpha sets opacity, edgecolors help datapoint stand out https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html
plt.title(f"GBL Wines Points vs Price Scatter")
plt.ylabel("Price ($)")
plt.xlabel("Reviewed Point Value")
plt.grid(True) 
plt.tight_layout() 
# tight_layout. This module provides routines to adjust subplot params so that subplots are nicely fit in the figure. https://matplotlib.org/api/tight_layout_api.html
plt.show()

# %%
x_values = clean_gbl_wines_noca['points'].astype(float)
y_values = clean_gbl_wines_noca['price'].astype(float)

# Calculate Pearson r value
print(f"The correlation coefficient between Review Points and Price is {round(st.pearsonr(x_values,y_values)[0],2)} for GBL Wines not from CA")

# Calculate line for plot
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plot and labels

plt.figure(figsize=(17, 17))
plt.title(f"GBL Wines Points vs Price LinReg")
plt.scatter(x_values,y_values, alpha=.75, edgecolors="k") 
# x,y required , alpha sets opacity, edgecolors help datapoint stand out https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(80,200),fontsize=15,color="red")
plt.ylabel("Price ($)")
plt.xlabel("Reviewed Point Value")
plt.grid(True) 
plt.tight_layout() 
plt.show()
# Out:
# The correlation coefficient between Review Points and Price is 0.53 for GBL Wines not from CA

# %%
good_value_wines = clean_gbl_wines.loc[(clean_gbl_wines['price'] <= 20) & (clean_gbl_wines['points'] >= 94)]
good_value_wines
# 18135         Moscato Giallo               Uvaggio
# 19970               Riesling                Januik
# 22252               Riesling            David Hill
# 23049               Riesling                Dunham
# 23050  Rhône-style Red Blend           Kevin White
# 23942               Riesling           Poet's Leap
# 26738                  Syrah                  Rulo
# 32870           Petite Sirah         Michael David
# 33550               Riesling           Poet's Leap

# %%
good_value_wines3 = clean_wine_df3.loc[(clean_wine_df3['price'] <= 20) & (clean_wine_df3['points'] >= 94)]
good_value_wines3
# Out:
#         Unnamed: 0    country  points  price           province  \
# 5011          5011         US      95   20.0         Washington
# 6267          6267         US      94   18.0         Washington
# 15196        15196     France      95   20.0   Southwest France
# 17294        17294         US      94   20.0         Washington
# 17983        17983     France      94   20.0           Provence
# 19136        19136      Spain      94   14.0          Andalucia
# 20364        20364     France      94   20.0             Alsace
# 26432        26432      Italy      94   20.0  Sicily & Sardinia
# 32258        32258         US      94   20.0             Oregon
# 39318        39318     France      94   18.0   Southwest France
# 51389        51389  Australia      94   19.0    South Australia
# 54276        54276         US      94   20.0         Washington
# 59290        59290         US      94   20.0         Washington
# 59303        59303         US      94   20.0         Washington
# 59405        59405     France      94   20.0         Beaujolais
# 69523        69523         US      94   20.0         Washington
# 69526        69526         US      94   16.0         California
# 76570        76570         US      95   20.0         Washington
# 84597        84597         US      94   18.0             Oregon
# 87618        87618         US      94   20.0         Washington
# 87619        87619         US      94   20.0         Washington
# 90951        90951         US      94   20.0         Washington
# 101580      101580         US      96   20.0         Washington
# 116845      116845      Italy      94   20.0             Veneto
# 117839      117839     France      94   20.0   Southwest France
# 117857      117857     France      94   20.0   Southwest France
# 123776      123776         US      94   18.0         California
# 126242      126242         US      95   20.0         Washington
#
#                          region_1        taster_name  \
# 5011         Columbia Valley (WA)       Paul Gregutt
# 6267                Yakima Valley       Paul Gregutt
# 15196                     Madiran         Roger Voss
# 17294               Yakima Valley       Paul Gregutt
# 17983   Coteaux d'Aix-en-Provence         Roger Voss
# 19136                       Jerez  Michael Schachner
# 20364                      Alsace         Roger Voss
# 26432             Terre Siciliane      Kerin O’Keefe
# 32258          Chehalem Mountains       Paul Gregutt
# 39318                    Jurançon         Roger Voss
# 51389                McLaren Vale     Joe Czerwinski
# 54276        Columbia Valley (WA)       Paul Gregutt
# 59290        Columbia Valley (WA)       Paul Gregutt
# 59303                Red Mountain       Paul Gregutt
# 59405               Moulin-à-Vent         Roger Voss
# 69523        Columbia Valley (WA)       Paul Gregutt
# 69526                        Lodi     Virginie Boone
# 76570        Columbia Valley (WA)       Paul Gregutt
# 84597           Willamette Valley       Paul Gregutt
# 87618        Columbia Valley (WA)       Paul Gregutt
# 87619               Yakima Valley       Paul Gregutt
# 90951        Columbia Valley (WA)       Paul Gregutt
# 101580       Columbia Valley (WA)       Paul Gregutt
# 116845                  Bardolino      Kerin O’Keefe
# 117839                    Madiran         Roger Voss
# 117857                     Cahors         Roger Voss
# 123776                       Lodi         Jim Gordon
