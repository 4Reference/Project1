# %% [markdown]
# # Wines of Texas

# %%
#Dependancies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import re

# %%
wines_csv = "dropped_wine_data.csv"
wine_df = pd.read_csv(wines_csv)
wine_df.head()
# Out:
#    Unnamed: 0   country  points  price           province  \
# 0           0     Italy      87    NaN  Sicily & Sardinia
# 1           1  Portugal      87   15.0              Douro
# 2           2        US      87   14.0             Oregon
# 3           3        US      87   13.0           Michigan
# 4           4        US      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
print([wine_df.count()])
# Out:
# [Unnamed: 0     129971
# country        129908
# points         129971
# price          120975
# province       129908
# region_1       108724
# region_2        50511
# taster_name    103727
# title          129971
# variety        129970
# winery         129971
# dtype: int64]

# %%
#drop old index from data
wine_df2 = wine_df.drop(columns='Unnamed: 0', axis=1)
print([wine_df2])
wine_df2.info()
# Out:
# [         country  points  price           province             region_1  \
# 0          Italy      87    NaN  Sicily & Sardinia                 Etna
# 1       Portugal      87   15.0              Douro                  NaN
# 2             US      87   14.0             Oregon    Willamette Valley
# 3             US      87   13.0           Michigan  Lake Michigan Shore
# 4             US      87   65.0             Oregon    Willamette Valley
# ...          ...     ...    ...                ...                  ...
# 129966   Germany      90   28.0              Mosel                  NaN
# 129967        US      90   75.0             Oregon               Oregon
# 129968    France      90   30.0             Alsace               Alsace
# 129969    France      90   32.0             Alsace               Alsace
# 129970    France      90   21.0             Alsace               Alsace
#
#                  region_2         taster_name  \
# 0                     NaN       Kerin O’Keefe
# 1                     NaN          Roger Voss
# 2       Willamette Valley        Paul Gregutt
# 3                     NaN  Alexander Peartree
# 4       Willamette Valley        Paul Gregutt
# ...                   ...                 ...
# 129966                NaN  Anna Lee C. Iijima
# 129967       Oregon Other        Paul Gregutt
# 129968                NaN          Roger Voss
# 129969                NaN          Roger Voss
# 129970                NaN          Roger Voss
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 10 columns]]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 10 columns):
# country        129908 non-null object
# points         129971 non-null int64
# price          120975 non-null float64
# province       129908 non-null object
# region_1       108724 non-null object
# region_2       50511 non-null object
# taster_name    103727 non-null object
# title          129971 non-null object
# variety        129970 non-null object
# winery         129971 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 9.9+ MB

# %%
#Create single region column
index = 0

for index, row in wine_df2.iterrows():
    if wine_df2.loc[index, 'region_1'] == wine_df2.loc[index, 'region_2']:
        wine_df2.loc[index, 'region_2'] = np.nan

wine_df2
# Out:
#          country  points  price           province             region_1  \
# 0          Italy      87    NaN  Sicily & Sardinia                 Etna
# 1       Portugal      87   15.0              Douro                  NaN
# 2             US      87   14.0             Oregon    Willamette Valley
# 3             US      87   13.0           Michigan  Lake Michigan Shore
# 4             US      87   65.0             Oregon    Willamette Valley
# ...          ...     ...    ...                ...                  ...
# 129966   Germany      90   28.0              Mosel                  NaN
# 129967        US      90   75.0             Oregon               Oregon
# 129968    France      90   30.0             Alsace               Alsace
# 129969    France      90   32.0             Alsace               Alsace
# 129970    France      90   21.0             Alsace               Alsace
#
#             region_2         taster_name  \
# 0                NaN       Kerin O’Keefe
# 1                NaN          Roger Voss
# 2                NaN        Paul Gregutt
# 3                NaN  Alexander Peartree
# 4                NaN        Paul Gregutt
# ...              ...                 ...
# 129966           NaN  Anna Lee C. Iijima
# 129967  Oregon Other        Paul Gregutt
# 129968           NaN          Roger Voss
# 129969           NaN          Roger Voss
# 129970           NaN          Roger Voss
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery  year
# 0                                        Nicosia  2014
# 1                            Quinta dos Avidagos  2014
# 2                                      Rainstorm  2014
# 3                                     St. Julian  2014
# 4                                   Sweet Cheeks  2014
# ...                                          ...   ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)  2014
# 129967                                  Citation  2014
# 129968                           Domaine Gresser  2014
# 129969                      Domaine Marcel Deiss  2014
# 129970                          Domaine Schoffit  2014
#
# [129971 rows x 11 columns]

# %%
print([wine_df2.count()])
wine_df2.info()
# Out:
# [country        129908
# points         129971
# price          120975
# province       129908
# region_1       108724
# region_2        50511
# taster_name    103727
# title          129971
# variety        129970
# winery         129971
# dtype: int64]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 10 columns):
# country        129908 non-null object
# points         129971 non-null int64
# price          120975 non-null float64
# province       129908 non-null object
# region_1       108724 non-null object
# region_2       50511 non-null object
# taster_name    103727 non-null object
# title          129971 non-null object
# variety        129970 non-null object
# winery         129971 non-null object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 9.9+ MB

# %%
wine_df2
# Out:
#          country  points  price           province             region_1  \
# 0          Italy      87    NaN  Sicily & Sardinia                 Etna
# 1       Portugal      87   15.0              Douro                  NaN
# 2             US      87   14.0             Oregon    Willamette Valley
# 3             US      87   13.0           Michigan  Lake Michigan Shore
# 4             US      87   65.0             Oregon    Willamette Valley
# ...          ...     ...    ...                ...                  ...
# 129966   Germany      90   28.0              Mosel                  NaN
# 129967        US      90   75.0             Oregon               Oregon
# 129968    France      90   30.0             Alsace               Alsace
# 129969    France      90   32.0             Alsace               Alsace
# 129970    France      90   21.0             Alsace               Alsace
#
#                  region_2         taster_name  \
# 0                     NaN       Kerin O’Keefe
# 1                     NaN          Roger Voss
# 2       Willamette Valley        Paul Gregutt
# 3                     NaN  Alexander Peartree
# 4       Willamette Valley        Paul Gregutt
# ...                   ...                 ...
# 129966                NaN  Anna Lee C. Iijima
# 129967       Oregon Other        Paul Gregutt
# 129968                NaN          Roger Voss
# 129969                NaN          Roger Voss
# 129970                NaN          Roger Voss
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 10 columns]

# %%
# Find Califorinian wines
california_wines = wine_df2.loc[wine_df2['province'] == "California"]
california_wines
# Out:
#        country  points  price    province           region_1       region_2  \
# 10          US      87   19.0  California        Napa Valley           Napa
# 12          US      87   34.0  California   Alexander Valley         Sonoma
# 14          US      87   12.0  California      Central Coast  Central Coast
# 23          US      87   22.0  California        Paso Robles  Central Coast
# 25          US      87   69.0  California       Sonoma Coast         Sonoma
# ...        ...     ...    ...         ...                ...            ...
# 129942      US      90   35.0  California      Sonoma County         Sonoma
# 129945      US      90   20.0  California  Santa Ynez Valley  Central Coast
# 129949      US      90   35.0  California        Napa Valley           Napa
# 129950      US      90   35.0  California        Napa Valley           Napa
# 129952      US      90   22.0  California      Chiles Valley           Napa
#
#            taster_name                                              title  \
# 10      Virginie Boone  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 12      Virginie Boone  Louis M. Martini 2012 Cabernet Sauvignon (Alex...
# 14       Matt Kettmann           Mirassou 2012 Chardonnay (Central Coast)
# 23       Matt Kettmann  Bianchi 2011 Signature Selection Merlot (Paso ...
# 25      Virginie Boone  Castello di Amorosa 2011 King Ridge Vineyard P...
# ...                ...                                                ...
# 129942  Virginie Boone   Arrowood 2010 Cabernet Sauvignon (Sonoma County)
# 129945   Matt Kettmann  Birichino 2013 Jurassic Park Vineyard Old Vine...
# 129949  Virginie Boone  Flora Springs 2013 Barrel Fermented Chardonnay...
# 129950  Virginie Boone  Hendry 2012 Blocks 7 & 22 Zinfandel (Napa Valley)
# 129952  Virginie Boone             Houdini 2011 Zinfandel (Chiles Valley)
#
#                    variety               winery
# 10      Cabernet Sauvignon   Kirkland Signature
# 12      Cabernet Sauvignon     Louis M. Martini
# 14              Chardonnay             Mirassou
# 23                  Merlot              Bianchi
# 25              Pinot Noir  Castello di Amorosa
# ...                    ...                  ...
# 129942  Cabernet Sauvignon             Arrowood
# 129945        Chenin Blanc            Birichino
# 129949          Chardonnay        Flora Springs
# 129950           Zinfandel               Hendry
# 129952           Zinfandel              Houdini
#
# [36247 rows x 10 columns]

# %%
clean_ca_wines = california_wines.dropna()
clean_ca_wines
# Out:
#        country  points  price    province           region_1       region_2  \
# 10          US      87   19.0  California        Napa Valley           Napa
# 12          US      87   34.0  California   Alexander Valley         Sonoma
# 14          US      87   12.0  California      Central Coast  Central Coast
# 23          US      87   22.0  California        Paso Robles  Central Coast
# 25          US      87   69.0  California       Sonoma Coast         Sonoma
# ...        ...     ...    ...         ...                ...            ...
# 129942      US      90   35.0  California      Sonoma County         Sonoma
# 129945      US      90   20.0  California  Santa Ynez Valley  Central Coast
# 129949      US      90   35.0  California        Napa Valley           Napa
# 129950      US      90   35.0  California        Napa Valley           Napa
# 129952      US      90   22.0  California      Chiles Valley           Napa
#
#            taster_name                                              title  \
# 10      Virginie Boone  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 12      Virginie Boone  Louis M. Martini 2012 Cabernet Sauvignon (Alex...
# 14       Matt Kettmann           Mirassou 2012 Chardonnay (Central Coast)
# 23       Matt Kettmann  Bianchi 2011 Signature Selection Merlot (Paso ...
# 25      Virginie Boone  Castello di Amorosa 2011 King Ridge Vineyard P...
# ...                ...                                                ...
# 129942  Virginie Boone   Arrowood 2010 Cabernet Sauvignon (Sonoma County)
# 129945   Matt Kettmann  Birichino 2013 Jurassic Park Vineyard Old Vine...
# 129949  Virginie Boone  Flora Springs 2013 Barrel Fermented Chardonnay...
# 129950  Virginie Boone  Hendry 2012 Blocks 7 & 22 Zinfandel (Napa Valley)
# 129952  Virginie Boone             Houdini 2011 Zinfandel (Chiles Valley)
#
#                    variety               winery
# 10      Cabernet Sauvignon   Kirkland Signature
# 12      Cabernet Sauvignon     Louis M. Martini
# 14              Chardonnay             Mirassou
# 23                  Merlot              Bianchi
# 25              Pinot Noir  Castello di Amorosa
# ...                    ...                  ...
# 129942  Cabernet Sauvignon             Arrowood
# 129945        Chenin Blanc            Birichino
# 129949          Chardonnay        Flora Springs
# 129950           Zinfandel               Hendry
# 129952           Zinfandel              Houdini
#
# [18384 rows x 10 columns]

# %%
#ordered list of counts of CA wines
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-59-dba2bbda324a> in <module>
#       1 #ordered list of counts of CA wines
#       2 ca_varietal_count = clean_ca_wines.groupby('variety').count()
# ----> 3 ca_varietal_count['title'].count().sort()
#
# AxisError: axis -1 is out of bounds for array of dimension 0

# %%
clean_gbl_wines = wine_df.dropna()
clean_gbl_wines
# Out:
#         Unnamed: 0 country  points  price    province           region_1  \
# 2                2      US      87   14.0      Oregon  Willamette Valley
# 4                4      US      87   65.0      Oregon  Willamette Valley
# 10              10      US      87   19.0  California        Napa Valley
# 12              12      US      87   34.0  California   Alexander Valley
# 14              14      US      87   12.0  California      Central Coast
# ...            ...     ...     ...    ...         ...                ...
# 129945      129945      US      90   20.0  California  Santa Ynez Valley
# 129949      129949      US      90   35.0  California        Napa Valley
# 129950      129950      US      90   35.0  California        Napa Valley
# 129952      129952      US      90   22.0  California      Chiles Valley
# 129967      129967      US      90   75.0      Oregon             Oregon
#
#                  region_2     taster_name  \
# 2       Willamette Valley    Paul Gregutt
# 4       Willamette Valley    Paul Gregutt
# 10                   Napa  Virginie Boone
# 12                 Sonoma  Virginie Boone
# 14          Central Coast   Matt Kettmann
# ...                   ...             ...
# 129945      Central Coast   Matt Kettmann
# 129949               Napa  Virginie Boone
# 129950               Napa  Virginie Boone
# 129952               Napa  Virginie Boone
# 129967       Oregon Other    Paul Gregutt
#
#                                                     title             variety  \
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 10      Kirkland Signature 2011 Mountain Cuvée Caberne...  Cabernet Sauvignon
# 12      Louis M. Martini 2012 Cabernet Sauvignon (Alex...  Cabernet Sauvignon
# 14               Mirassou 2012 Chardonnay (Central Coast)          Chardonnay
# ...                                                   ...                 ...
# 129945  Birichino 2013 Jurassic Park Vineyard Old Vine...        Chenin Blanc
# 129949  Flora Springs 2013 Barrel Fermented Chardonnay...          Chardonnay
# 129950  Hendry 2012 Blocks 7 & 22 Zinfandel (Napa Valley)           Zinfandel
# 129952             Houdini 2011 Zinfandel (Chiles Valley)           Zinfandel
# 129967                  Citation 2004 Pinot Noir (Oregon)          Pinot Noir
#
#                     winery
# 2                Rainstorm
# 4             Sweet Cheeks
# 10      Kirkland Signature
# 12        Louis M. Martini
# 14                Mirassou
# ...                    ...
# 129945           Birichino
# 129949       Flora Springs
# 129950              Hendry
# 129952             Houdini
# 129967            Citation
#
# [34559 rows x 11 columns]

# %%
clean_gbl_wines_noca = clean_gbl_wines.loc[clean_gbl_wines['province'] != "California"]
clean_gbl_wines_noca
# Out:
#         Unnamed: 0 country  points  price    province  \
# 2                2      US      87   14.0      Oregon
# 4                4      US      87   65.0      Oregon
# 21              21      US      87   20.0      Oregon
# 35              35      US      86   50.0      Oregon
# 41              41      US      86   22.0      Oregon
# ...            ...     ...     ...    ...         ...
# 129919      129919      US      91  105.0  Washington
# 129926      129926      US      91   41.0  Washington
# 129927      129927      US      91   28.0  Washington
# 129935      129935      US      91   38.0  Washington
# 129967      129967      US      90   75.0      Oregon
#
#                                   region_1           region_2   taster_name  \
# 2                        Willamette Valley  Willamette Valley  Paul Gregutt
# 4                        Willamette Valley  Willamette Valley  Paul Gregutt
# 21                                  Oregon       Oregon Other  Paul Gregutt
# 35                             McMinnville  Willamette Valley  Paul Gregutt
# 41                       Willamette Valley  Willamette Valley  Paul Gregutt
# ...                                    ...                ...           ...
# 129919             Walla Walla Valley (WA)    Columbia Valley  Paul Gregutt
# 129926             Walla Walla Valley (WA)    Columbia Valley  Paul Gregutt
# 129927                Columbia Valley (WA)    Columbia Valley  Paul Gregutt
# 129935  Columbia Valley-Walla Walla Valley    Columbia Valley  Paul Gregutt
# 129967                              Oregon       Oregon Other  Paul Gregutt
#
#                                                     title         variety  \
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# 21                       Acrobat 2013 Pinot Noir (Oregon)      Pinot Noir
# 35             Erath 2010 Hyland Pinot Noir (McMinnville)      Pinot Noir
# 41      Hawkins Cellars 2009 Pinot Noir (Willamette Va...      Pinot Noir
# ...                                                   ...             ...
# 129919  Nicholas Cole Cellars 2004 Reserve Red (Walla ...       Red Blend
# 129926  Reininger 2005 Ash Hollow Vineyard Syrah (Wall...           Syrah
# 129927  Tamarack Cellars 2006 Cabernet Franc (Columbia...  Cabernet Franc
# 129935  Va Piano 2006 Syrah (Columbia Valley-Walla Wal...           Syrah
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
#
#                        winery
# 2                   Rainstorm
# 4                Sweet Cheeks
# 21                    Acrobat
# 35                      Erath
# 41            Hawkins Cellars
# ...                       ...
# 129919  Nicholas Cole Cellars
# 129926              Reininger
# 129927       Tamarack Cellars
# 129935               Va Piano
# 129967               Citation
#
# [16175 rows x 11 columns]

# %%
#ordered list of counts of CA wines
ca_varietal = clean_ca_wines.groupby('variety')
ca_type_count = ca_varietal['title'].count()
print([ca_type_count.sort_values(ascending=False).head(20)])
ca_type_count.plot.pie(figsize=(17,17),subplots=True,autopct='%1.1f%%')
# Out:
# [variety
# Pinot Noir                  3572
# Chardonnay                  2587
# Cabernet Sauvignon          2545
# Zinfandel                   1380
# Red Blend                   1054
# Syrah                        940
# Sauvignon Blanc              854
# Merlot                       533
# Bordeaux-style Red Blend     405
# Petite Sirah                 376
# Rhône-style Red Blend        340
# Rosé                         324
# Sparkling Blend              254
# Grenache                     249
# Viognier                     242
# White Blend                  201
# Cabernet Franc               201
# Barbera                      147
# Pinot Grigio                 131
# Sangiovese                   128
# Name: title, dtype: int64]
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B365B58608>],
#       dtype=object)

# %%
gbl_varietal = clean_gbl_wines.groupby('variety')
gbl_type_count = gbl_varietal['title'].count()
print([gbl_type_count.sort_values(ascending=False).head(20)])
gbl_type_count.plot.pie(figsize=(17,17),subplots=True,autopct='%1.1f%%')
# Out:
# [variety
# Pinot Noir                  6260
# Cabernet Sauvignon          4081
# Chardonnay                  4005
# Syrah                       2254
# Red Blend                   2058
# Riesling                    1470
# Zinfandel                   1449
# Merlot                      1362
# Bordeaux-style Red Blend    1248
# Sauvignon Blanc             1178
# Pinot Gris                   710
# Cabernet Franc               698
# Rosé                         667
# Rhône-style Red Blend        527
# Viognier                     498
# Malbec                       445
# Petite Sirah                 417
# White Blend                  406
# Grenache                     394
# Sparkling Blend              358
# Name: title, dtype: int64]
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B3652B4D48>],
#       dtype=object)

# %%
noca_gbl_varietal = clean_gbl_wines_noca.groupby('variety')
noca_gbl_type_count = noca_gbl_varietal['title'].count()
print([noca_gbl_type_count.sort_values(ascending=False).head(20)])
noca_gbl_type_count.plot.pie(figsize=(17,17),subplots=True,autopct='%1.1f%%')
# Out:
# [variety
# Pinot Noir                  2688
# Cabernet Sauvignon          1536
# Chardonnay                  1418
# Riesling                    1365
# Syrah                       1314
# Red Blend                   1004
# Bordeaux-style Red Blend     843
# Merlot                       829
# Pinot Gris                   631
# Cabernet Franc               497
# Rosé                         343
# Sauvignon Blanc              324
# Malbec                       320
# Viognier                     256
# Gewürztraminer               250
# White Blend                  205
# Rhône-style Red Blend        187
# Tempranillo                  180
# Sangiovese                   158
# Grenache                     145
# Name: title, dtype: int64]
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B367082BC8>],
#       dtype=object)

# %%
# extract year from column title
